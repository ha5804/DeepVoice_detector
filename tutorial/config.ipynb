# %% [markdown]
# # 1.config
#
# ### Definition
# - 일반적으로 config 파일에서는, 변수를 저장하는 역할을 한다.
# config에 저장된 변수들로 쉽게 코드를 수정할 수 있다.
#
# #### 이때 config에 작성된 내용은 dict파일로 저장되어 추후에 dict형식으로 접근해야 한다.

# %%
data:

  train_path: /Users/taehayeong/Desktop/data/deepvoice_data/train_data
  test_path: /Users/taehayeong/Desktop/data/deepvoice_data/test_data

  sample_rate: 16000
  n_mels: 4
  segment_frames: 300 
  max_samples: 500
