# %% [markdown]
# DataLoader에서 나오는 x shape은 (B, 80, 300)이다.
# 이때 B는 batch size, 80은 n_mels, 300은 segment_frames이다.

# %%
import torch.nn as nn

class LSTMAutoEncoder(nn.Module):
    def __init__(
        self,
        n_mels = 80,
        hidden_dim = 128,
        latent_dim = 64,
        num_layers = 2
    ):
        super().__init__()

        self.encoder = nn.LSTM(
            input_size = n_mels,
            hidden_size = hidden_dim,
            num_layers = num_la
        )
